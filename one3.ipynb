# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekthakur2602/Nlp_text_1/blob/single_notebook/one3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandas scikit-learn torch transformers

# %%
from transformers import TrainingArguments
print(TrainingArguments.__init__.__code__.co_varnames)
# Out:
# /Users/abhisheksingh/Documents/Jbooks/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch

# Load your dataset
df = pd.read_csv("/content/civic_issues_dataset_8k_plus.csv")

print(df.head())
print(df['department'].value_counts())
# Out:
#                                          description               department  \
# 0  There is fallen wire and गाँव वाले बहुत परेशान...  Electricity/Streetlight
# 1  burst pipe के कारण पूरी गली में समस्या हो रही ...             Water Supply
# 2  poordrainageकेकारणबच्चोंऔरबुजुर्गोंकेलिएबाहरनि...       Flood/Waterlogging
# 3  Theoverflowingbinshasbeenaffectingourlocalityf...               Sanitation
# 4  For the past week, food poisoning has caused a...                   Health
#
#          issue_type  priority
# 0       fallen wire  Critical
# 1        burst pipe      High
# 2     poor drainage    Medium
# 3  overflowing bins    Medium
# 4    food poisoning    Medium
# department
# Unknown                    1429
# Water Supply                844
# Roads                       813
# Health                      810
# Animal Issues               795
# Protest/Traffic             790
# Electricity/Streetlight     789
# Urban Development           785
# Flood/Waterlogging          770
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                             description  \
# 0     There is fallen wire and गाँव वाले बहुत परेशान...
# 1     burst pipe के कारण पूरी गली में समस्या हो रही ...
# 2     poordrainageकेकारणबच्चोंऔरबुजुर्गोंकेलिएबाहरनि...
# 3     Theoverflowingbinshasbeenaffectingourlocalityf...
# 4     For the past week, food poisoning has caused a...
# ...                                                 ...
# 9295  Residentsofourcolonyaresufferingduetoflickerin...
# 9296  There is serious dogs menace in front of my ho...
# 9297  overflowing bins के कारण पूरी गली में समस्या ह...
# 9298                       trash not collected reported
# 9299                                   garbage reported
#
#                    department           issue_type  priority
# 0     Electricity/Streetlight          fallen wire  Critical
# 1                Water Supply           burst pipe      High
# 2          Flood/Waterlogging        poor drainage    Medium
# ...

# %%
df.info

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Drop rows with missing descriptions
df = df[df['description'].notna()]

X = df['description']
y = df['department']

# Encode department labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print("Classes:", label_encoder.classes_)
# Out:
# Classes: ['Animal Issues' 'Electricity/Streetlight' 'Flood/Waterlogging' 'Health'
#  'Noise Pollution' 'Protest/Traffic' 'Roads' 'Sanitation' 'Unknown'
#  'Urban Development' 'Water Supply']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# Build pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2), max_features=20000)),
    ('clf', LogisticRegression(max_iter=500))
])

# Train
pipeline.fit(X_train, y_train)

# Evaluate
y_pred = pipeline.predict(X_test)
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
#                          precision    recall  f1-score   support
#
#           Animal Issues       0.95      0.94      0.95       159
# Electricity/Streetlight       0.99      0.97      0.98       158
#      Flood/Waterlogging       0.89      0.95      0.92       154
#                  Health       0.94      0.96      0.95       162
#         Noise Pollution       0.99      0.97      0.98       143
#         Protest/Traffic       0.94      0.97      0.96       158
#                   Roads       0.92      0.97      0.94       163
#              Sanitation       0.96      0.91      0.94       151
#                 Unknown       1.00      0.98      0.99       226
#       Urban Development       0.97      0.92      0.95       157
#            Water Supply       0.96      0.96      0.96       169
#
#                accuracy                           0.96      1800
#               macro avg       0.96      0.96      0.96      1800
# ...

# %%
import transformers
print(transformers.__version__)

# %%
! pip show transformers
! pip show accelerate

# %%
! pip install accelerate

# %%
from transformers import TrainingArguments
import transformers
print(transformers.__version__)
print(TrainingArguments.__module__)

# %%
import transformers
print(transformers.__version__)
print(transformers.__file__)

# %%
from transformers import TrainingArguments
help(TrainingArguments)

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments
import torch
from torch.utils.data import Dataset

# ✅ Use DistilBERT tokenizer
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

class CivicDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=32):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = self.labels[idx]
        encoding = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_len,
            return_tensors="pt"
        )
        return {
            "input_ids": encoding["input_ids"].flatten(),
            "attention_mask": encoding["attention_mask"].flatten(),
            "labels": torch.tensor(label, dtype=torch.long)
        }

# ✅ Datasets
train_dataset = CivicDataset(X_train.tolist(), y_train, tokenizer)
test_dataset  = CivicDataset(X_test.tolist(), y_test, tokenizer)

# ✅ Load DistilBERT model (not Bert!)
model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=len(label_encoder.classes_)
)

# ✅ Training arguments (fix param name)
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=1,   # quick run
    weight_decay=0.01,
    fp16=True  # ✅ mixed precision speeds up on GPU
)

# ✅ Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset
)

# ✅ Train
trainer.train()
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='554' max='900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [554/900 15:19 < 09:36, 0.60 it/s, Epoch 0.61/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
results = trainer.evaluate(test_dataset)
print(results)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='225' max='225' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [225/225 02:43]
#     </div>
# {'eval_loss': 0.044517889618873596, 'eval_runtime': 164.1421, 'eval_samples_per_second': 10.966, 'eval_steps_per_second': 1.371, 'epoch': 1.0}

# %%
import numpy as np
from sklearn.metrics import classification_report

preds_output = trainer.predict(test_dataset)
y_true = preds_output.label_ids
y_pred = np.argmax(preds_output.predictions, axis=1)

print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))
# Out:
#                          precision    recall  f1-score   support
#
#           Animal Issues       0.90      0.99      0.94       159
# Electricity/Streetlight       0.99      1.00      1.00       158
#      Flood/Waterlogging       0.99      0.99      0.99       154
#                  Health       0.99      0.99      0.99       162
#         Noise Pollution       1.00      0.99      0.99       143
#         Protest/Traffic       1.00      0.99      0.99       158
#                   Roads       0.99      0.99      0.99       163
#              Sanitation       1.00      0.97      0.99       151
#                 Unknown       1.00      0.99      1.00       226
#       Urban Development       0.99      0.97      0.98       157
#            Water Supply       0.99      0.99      0.99       169
#
#                accuracy                           0.99      1800
#               macro avg       0.99      0.99      0.99      1800
# ...

# %%
from transformers import pipeline

classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

print(classifier("The streetlights are not working on my road."))
print(classifier("There is sewage overflow near my house."))
print(classifier("The power supply is down since yesterday."))
# Out:
# Device set to use cpu
# [{'label': 'LABEL_1', 'score': 0.9910159111022949}]
# [{'label': 'LABEL_7', 'score': 0.9934456944465637}]
# [{'label': 'LABEL_1', 'score': 0.894111156463623}]

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, pipeline

# ✅ Create mapping from label encoder
id2label = {i: label for i, label in enumerate(label_encoder.classes_)}
label2id = {label: i for i, label in enumerate(label_encoder.classes_)}

# ✅ Reload fine-tuned DistilBERT model with mapping
model = DistilBertForSequenceClassification.from_pretrained(
    "/content/results/checkpoint-900",   # <-- replace with latest checkpoint
    num_labels=len(label_encoder.classes_),
    id2label=id2label,
    label2id=label2id
)

# ✅ Reload tokenizer
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

# ✅ Recreate pipeline
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# ✅ Test predictions
print(classifier("The streetlights are not working on my road."))
print(classifier("There is sewage overflow near my house."))
print(classifier("The power supply is down since yesterday."))
# Out:
# Device set to use cpu
# [{'label': 'Electricity/Streetlight', 'score': 0.9910159111022949}]
# [{'label': 'Sanitation', 'score': 0.9934456944465637}]
# [{'label': 'Electricity/Streetlight', 'score': 0.894111156463623}]

# %%
print(label_encoder.classes_)  # should list all your department names
print(id2label)
# Out:
# ['Animal Issues' 'Electricity/Streetlight' 'Flood/Waterlogging' 'Health'
#  'Noise Pollution' 'Protest/Traffic' 'Roads' 'Sanitation' 'Unknown'
#  'Urban Development' 'Water Supply']
# {0: 'Animal Issues', 1: 'Electricity/Streetlight', 2: 'Flood/Waterlogging', 3: 'Health', 4: 'Noise Pollution', 5: 'Protest/Traffic', 6: 'Roads', 7: 'Sanitation', 8: 'Unknown', 9: 'Urban Development', 10: 'Water Supply'}

# %%
trainer.save_model("./dept_model")
tokenizer.save_pretrained("./dept_model")
# Out:
# ('./dept_model/tokenizer_config.json',
#  './dept_model/special_tokens_map.json',
#  './dept_model/vocab.txt',
#  './dept_model/added_tokens.json')

# %%
from transformers import pipeline, DistilBertForSequenceClassification, DistilBertTokenizer

# Load fine-tuned model + tokenizer from saved folder
model = DistilBertForSequenceClassification.from_pretrained("./dept_model")
tokenizer = DistilBertTokenizer.from_pretrained("./dept_model")

# Create classifier pipeline
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Test with sample text
print(classifier("The streetlights are broken on the main road."))
print(classifier("There is sewage overflow near my house."))
print(classifier("The power supply is down since yesterday."))
# Out:
# Device set to use cpu
# [{'label': 'LABEL_1', 'score': 0.9897559285163879}]
# [{'label': 'LABEL_7', 'score': 0.9934456944465637}]
# [{'label': 'LABEL_1', 'score': 0.894111156463623}]

# %%
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer, pipeline

# reload fine-tuned model
model = DistilBertForSequenceClassification.from_pretrained(
    "./dept_model",
    num_labels=11,
    id2label={
        0: 'Animal Issues',
        1: 'Electricity/Streetlight',
        2: 'Flood/Waterlogging',
        3: 'Health',
        4: 'Noise Pollution',
        5: 'Protest/Traffic',
        6: 'Roads',
        7: 'Sanitation',
        8: 'Unknown',
        9: 'Urban Development',
        10: 'Water Supply'
    },
    label2id={
        'Animal Issues': 0,
        'Electricity/Streetlight': 1,
        'Flood/Waterlogging': 2,
        'Health': 3,
        'Noise Pollution': 4,
        'Protest/Traffic': 5,
        'Roads': 6,
        'Sanitation': 7,
        'Unknown': 8,
        'Urban Development': 9,
        'Water Supply': 10
    }
)

tokenizer = DistilBertTokenizer.from_pretrained("./dept_model")

classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

print(classifier("The streetlights are broken on the main road."))
print(classifier("There is sewage overflow near my house."))
print(classifier("The power supply is down since yesterday."))
# Out:
# Device set to use cpu
# [{'label': 'Electricity/Streetlight', 'score': 0.9897559285163879}]
# [{'label': 'Sanitation', 'score': 0.9934456944465637}]
# [{'label': 'Electricity/Streetlight', 'score': 0.894111156463623}]

# %%
def predict_department(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    outputs = model(**inputs)
    pred = torch.argmax(outputs.logits, dim=1).item()
    return label_encoder.inverse_transform([pred])[0]

print(predict_department("Streetlight not working near my house"))
print(predict_department("पानी की सप्लाई पिछले 3 दिनों से बंद है"))
# Out:
# Electricity/Streetlight
# Unknown

# %%
with open("app.py", "w") as f:
    f.write("""import streamlit as st
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer, pipeline

# Label mappings
id2label = {
    0: 'Animal Issues',
    1: 'Electricity/Streetlight',
    2: 'Flood/Waterlogging',
    3: 'Health',
    4: 'Noise Pollution',
    5: 'Protest/Traffic',
    6: 'Roads',
    7: 'Sanitation',
    8: 'Unknown',
    9: 'Urban Development',
    10: 'Water Supply'
}
label2id = {v: k for k, v in id2label.items()}

# Load trained model
model = DistilBertForSequenceClassification.from_pretrained(
    "./dept_model",
    num_labels=len(id2label),
    id2label=id2label,
    label2id=label2id
)
tokenizer = DistilBertTokenizer.from_pretrained("./dept_model")
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Streamlit UI
st.title("Civic Complaint Classifier 🚦")
user_input = st.text_area("Enter complaint description:")

if st.button("Predict"):
    if user_input.strip():
        result = classifier(user_input, truncation=True)
        label = result[0]['label']
        score = result[0]['score']
        st.success(f"**Predicted Category:** {label} (Confidence: {score:.2f})")

    else:
        st.warning("⚠️ Please enter some text!")



""")

# %%
! pkill -f ngrok

# %%
# !ls /content
# Out:
# app.py				  dept_model  results	   wandb
# civic_issues_dataset_8k_plus.csv  logs.txt    sample_data

# %%
# !streamlit run app.py --server.port 8501 &>/content/logs.txt &

# %%
# !tail -n 20 /content/logs.txt
# Out:
# ...
#
# 2025-09-17 05:35:14.524 Port 8501 is already in use

# %%
from pyngrok import ngrok
public_url = ngrok.connect(8501)
print("Streamlit URL:", public_url)
# Out:
# Streamlit URL: NgrokTunnel: "https://2a300de9e65a.ngrok-free.app" -> "http://localhost:8501"

# %%
# !pip install streamlit pyngrok
from pyngrok import ngrok

# Create tunnel
public_url = ngrok.connect(8501)
print("Streamlit URL:", public_url)

# Run app
# !streamlit run app.py --server.port 8501 &
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 75.9 MB/s eta 0:00:00
# ...
# ERROR:pyngrok.process.ngrok:t=2025-09-17T05:18:50+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2025-09-17T05:18:50+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# ...

# %%
# !ngrok config add-authtoken 2yJG5ldoPyPnSvuk7OvmrZLLIyk_5bbQBn18mkTQWDaceBqPY
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
public_url = ngrok.connect(8501)
print("Streamlit URL:", public_url)
# Out:
# Streamlit URL: NgrokTunnel: "https://99fadb774b29.ngrok-free.app" -> "http://localhost:8501"
